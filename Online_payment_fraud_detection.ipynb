# %% [markdown]
# <a href="https://colab.research.google.com/github/Shriram0085/ML-projects/blob/main/Online_payment_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nomo Nayaran

# %% [markdown]
# # Online payment fraud dectection

# %% [markdown]
# Downlode the data set from Kaggel of the online payment prediction from the given link below
#
# link for the data set -> https://www.kaggle.com/datasets/rupakroy/online-payments-fraud-detection-dataset

# %%
# import required laberies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import plotly.express as px
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('/content/drive/MyDrive/Detasets/data_set.csv')
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df.shape
# Out:
# (6362620, 11)

# %%
type=df['type'].value_counts()

# %%
transactions=type.index

# %%
quantity = type.values

# %%
# ploting an pie chat
px.pie(df, values=quantity, names=transactions, title='Distribution of Transactions Type')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['type']=df['type'].map({'PAYMENT':1, 'TRANSFER':4, 'CASH_OUT':2, 'DEBIT':5, 'CASH_IN':3})

# %%
df
# Out:
#          step  type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1     1     9839.64  C1231006815      170136.00       160296.36
# 1           1     1     1864.28  C1666544295       21249.00        19384.72
# 2           1     4      181.00  C1305486145         181.00            0.00
# 3           1     2      181.00   C840083671         181.00            0.00
# 4           1     1    11668.14  C2048537720       41554.00        29885.86
# ...       ...   ...         ...          ...            ...             ...
# 6362615   743     2   339682.13   C786484425      339682.13            0.00
# 6362616   743     4  6311409.28  C1529008245     6311409.28            0.00
# 6362617   743     2  6311409.28  C1162922333     6311409.28            0.00
# 6362618   743     4   850002.52  C1685995037      850002.52            0.00
# 6362619   743     2   850002.52  C1280323807      850002.52            0.00
#
# ...

# %%
x=df[['type','amount','oldbalanceOrg','newbalanceOrig']]
y=df.iloc[:,-2]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
model=DecisionTreeClassifier()

model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
model.score(xtest,ytest)
# Out:
# 0.9997123826348265

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix
ypred = model.predict(xtest)
cm = confusion_matrix(ytest, ypred)

# %%
cm
# Out:
# array([[1270720,     184],
#        [    182,    1438]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
